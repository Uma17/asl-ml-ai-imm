# %% [markdown]
# <a href="https://colab.research.google.com/github/Uma17/asl-ml-ai-imm/blob/main/GradedQuiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For which of the following pairs of datatypes does the addition operation raise an error?
# int and string?

# %%
a = 10
b = 2.3
c = a*b
print(type(c))
# Out:
# <class 'float'>

# %%
i = '20'
if i > 20:
    print(1)
else:
    print(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4051671333.py in <cell line: 0>()
#       1 i = '20'
# ----> 2 if i > 20:
#       3     print(1)
#       4 else:
#       5     print(2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = 1
for i in range(1,6):
     a = a*i
print(a)
# Out:
# 120

# %%
# Which of the following codes will fetch the third element from the
# start of a list named new_list containing 4 elements?
new_list=['2','4','6','8']
new_list[-2]
# Out:
# '6'

# %%
alphabets = {'1':'A','2':'B','3': ['C','D','E']}
alphabets['3'][2]
# Out:
# 'E'

# %%
list = ["Great", 51, True, 46, "Hi"]
list[2:-1]
# Out:
# [True, 46]

# %%
list_mul = ['2','2','2']
list_mul*2
# Out:
# ['2', '2', '2', '2', '2', '2']

# %%
def fun(n):
  return n*n*n
fun(2)
# Out:
# 8

# %%
lambda_cube= lambda n:n*n*n
